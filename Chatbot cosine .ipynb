# %%
import pandas as pd
from sklearn.feature_extration.text import TfdfVectorizer
from sklearn.matrics.pairwise import cosine_similarity

# %%
df=pd.read_csv("Chatbot.csv")

# %%
df['search_text']=df['context'] + " " +df["question"]

# %%
vectorizer=TfidfVectorizer()
X=vectorizer.fit_transform(df['search_text'])

# %%
q=input('Question :')
q_vec=vectorizer.transform([q])
sims=cosine_similarity(q_vec,X)[0]
print("Similarities:",sims)
idx=sims.arg,ax()
prtint('\nAnswer:',df['answer'][idx])
print()
